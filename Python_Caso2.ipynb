# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianBaqui/Taller-Computaci-n-Python/blob/main/Python_Caso2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Caso de estudio Python
#
# "*Dormía y soñaba que la vida era alegría, desperté y vi que la vida era servicio, serví y vi que el servicio era alegría*".
#
# Rabindranath Tagore

# %% [markdown]
# ### **Instrucciones**
#
# Responda en este mismo archivo. El entregable será este archivo, en formato .ipynb
#
# **Importante:** Cada punto debe tener una **interpretación** de lo obtenido.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Contexto: Trabajas como analista de datos para SportInvest Analytics. Un grupo de inversores quiere invertir €500 millones en fútbol y necesita un análisis del mercado basado en datos.
#
# Dataset: 18,205 jugadores FIFA con información de rating, valor, salario, club y liga.
#
# **Tu misión: Responder 6 preguntas clave con análisis de datos y gráficos.**

# %% [markdown]
# #### Paso previo: Carga de los datos

# %%
import pandas as pd

## Leer los datos

# Ejecutar para poder ver todas las columnas
pd.set_option(/content/player-data-full-2025-june_cleaned.csv, None)

# df = pd.read_csv("")

## recuerde los métodos de head, describe, info, etc para poder tener una primera aproximación a los datos
# Out:
#   File "/tmp/ipython-input-1-619322642.py", line 6
#     pd.set_option(/content/player-data-full-2025-june_cleaned.csv, None)
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Preguntas de investigación

# %% [markdown]
# ### Pregunta 1 (10 puntos): Top Jugadores

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 2: Mejores equipos (10 puntos)
#
# Para esta pregunta, debe ordenar de mayor rating a menor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 3: Distribución del Rating (5 puntos)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 4: Análisis de ligas (10 puntos)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 5: Relación calidad-precio (10 puntos)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 6: Elabore una pregunta de investigación y dé la solución y su interpretación (5 puntos)

# %% [markdown]
# ### Bono: Cualquier otro análisis será tenido en cuenta ;)

# %% [markdown]
# ## Espacio para comentarios, sugerencias, etc...
